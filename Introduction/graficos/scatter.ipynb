# %%
# representação simples para entendimento de como funciona o gráfico scatter plot
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

rng = np.random.RandomState(0)
x = [1,2,3,4,5]
y = [5,2,3,4,5]
colors = rng.rand(5)
print('Colors = ', colors)

plt.scatter(x, y, c=colors,  alpha=0.3, cmap='viridis')
plt.colorbar();  # show color scale
# Out:
# Colors =  [0.5488135  0.71518937 0.60276338 0.54488318 0.4236548 ]

# %%
# sim agora vendo no conjunto de dados iris, o hello word 
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2, s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.colorbar();  # show color scale

# %%
plt.scatter(features[2], features[3], alpha=0.2, s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[2])
plt.ylabel(iris.feature_names[3])
plt.colorbar();  # show color scale

# %%
plt.scatter(features[1], features[3], alpha=0.2, s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[1])
plt.ylabel(iris.feature_names[3])
plt.colorbar();  # show color scale

# %%
plt.scatter(features[2], features[3], alpha=0.2, s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[2])
plt.ylabel(iris.feature_names[3])
plt.colorbar();  # show color scale
